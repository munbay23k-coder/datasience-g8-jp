# %%
print("hola mundo")
# Out:
# hola mundo

# %%
#variable texto , cadena, string
nombre: str ="jhair"
apellido:str="perez"

print(nombre +' '+ apellido)
mi_nombre_completo= f"Mi nombre completo es:{nombre} {apellido}"
print(mi_nombre_completo)
#variables numericas enteros o int
edad:int = 31
#variables numericas pero decimales o float
sueldo:float=9.99


print("mi edad dentro de 5 years:",edad+5)
print("mi edad hace 5 years:",edad-5)
print("el doble de mi edad:",edad*2)
print("la mitad de mi edad:",edad//2)
print("el resto de mi edad:",edad % 2)
# Out:
# jhair perez
# Mi nombre completo es:jhair perez
# mi edad dentro de 5 years: 36
# mi edad hace 5 years: 26
# el doble de mi edad: 62
# la mitad de mi edad: 15
# el resto de mi edad: 1

# %%
nombre= input("ingresa tu nombre:")

# %%
print(nombre)
# Out:
# jhair

# %%
edad= input("ingresa tu edad:")

# %%
type(edad)
# Out:
# str

# %%
edad_int=int(edad)

# %%
print(edad_int+5)
# Out:
# 37

# %%
#aca si se concatena
print(edad+"5")
# Out:
# 325
