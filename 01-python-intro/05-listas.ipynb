# %%
list(range(6))
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
lista_numeros=[0,1,2,3,4,5]
lista_nombres=["juan","ana","luis"]
lista_mixta=[0,0.1,0.5,"marcos","maria"]

# %%
for i in lista_mixta:
    print(i)
# Out:
# 0
# 0.1
# 0.5
# marcos
# maria

# %%
type(lista_numeros)
# Out:
# list

# %%
lista_numeros.append(8)
print(lista_numeros)
# Out:
# [0, 1, 2, 3, 4, 5, 8]

# %%
lista_numeros.append([1,3,5])
print(lista_numeros)
# Out:
# [0, 1, 2, 3, 4, 5, 8, [1, 3, 5], [1, 3, 5]]

# %%
lista_numeros.insert(0,"juan")
print(lista_numeros)
# Out:
# ['juan', 0, 1, 2, 3, 4, 5, 8, [1, 3, 5], [1, 3, 5]]

# %%
lista_numeros_2=[2,3,4,5]
lista_numeros_2.insert(-1,6)
print(lista_numeros_2)
# Out:
# [2, 3, 4, 6, 5]

# %%
lista_numeros_2.remove(4)
print(lista_numeros_2)
# Out:
# [2, 3, 6, 5]

# %%
lista_numeros_2.pop()

## remueve el ultimo elemento de la lista
# Out:
# 5

# %%
print(lista_numeros_2)
# Out:
# [2, 3, 6]

# %%
lista_numeros_2=[2,1,5,8,0]
sorted(lista_numeros_2,reverse=False)## ordena de manera acsendente o desendente
# Out:
# [0, 1, 2, 5, 8]
