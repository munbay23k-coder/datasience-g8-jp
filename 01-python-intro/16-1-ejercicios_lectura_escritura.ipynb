# %%
from typing import Any

def extract_text(ruta:str)->dict[str,Any]:
    mi_lista = []
    with open(ruta,"r") as f:
        contenido=f.read()
        lineas = contenido.split("\n")
    for linea in lineas:
        if "lista" in linea.lower():
            continue
        if not linea:
            continue
        if "instrucciones" in linea.lower():
            break

        mi_lista.append(linea)

    return mi_lista

contenido=extract_text(
    #
    "../data/estudiantes_python.txt"## ".." es para indicar que tome desde donde esta el archivo
)

# %%
class Estudiante:
    def __init__(self,nombre:str,edad:int,ciudad:str,nota:float)->None:
        self.nombre = nombre
        self.edad = edad
        self.ciudad = ciudad
        self.nota = nota

class Aula: ## aula tiene estudiantes (es composicion) si fuera , estudiante es un aula (seria herencia)
    def __init__(self,estudiantes:dict[str])->None:
        self.estudiantes:  list[Estudiante] = []

        for estudiante in estudiantes:
            info = [item.strip() for item in estudiante.split(",")]
            estudiante = Estudiante(
                nombre= info[0],
                edad = int(info[1]),
                ciudad =info[2],
                nota = float(info[3])
            )
            self.estudiantes.append(estudiante)

    def __len__(self)-> int:# se pone "__" porque len es una palabra reservada de python
        return len

    def filtro_por_ciudad(self,ciudad:str)->None:
        for estudiante in self.estudiantes:
            if estudiante.ciudad.lower() == ciudad:
                print(estudiante.nombre)

    def get_aprobados(self, min_nota:int=13)->list[str]:
        estudiantes = []
        for estudiante in self.estudiantes:
            if estudiante.nota >= min_nota:
                estudiantes.append(estudiante.nombre)

        return estudiantes

    def get_num_aprobados(self,min_nota:int = 13)->int:
        return len(self.get_aprobados(min_nota))

    def export_alumnos(self,ruta: str)-> None:
        with open(ruta, "w") as f:
            f.write("nombre, edad, ciudad, nota\n")

        for estudiante in self.estudiantes:
            with open(ruta,"a") as f:
                f.write(f"{estudiante.nombre}, {estudiante.edad}, {estudiante.ciudad}, {estudiante.nota}\n")


aula=Aula(contenido)

# %%
aula.filtro_por_ciudad("cusco")
# Out:
# MarÃ­a Quispe
# AndrÃ©s Castillo

# %%
aula.get_aprobados(16)
# Out:
# ['Ana Torres', 'MarÃ\xada Quispe', 'SofÃ\xada Vargas', 'Valeria Rojas']

# %%
aula.export_alumnos("../data/dato.csv")
