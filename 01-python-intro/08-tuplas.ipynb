# %%
lista=[1,3,5,7]
lista[0]=9
print(lista)
# Out:
# [9, 3, 5, 7]

# %%
### tupla es una lista que no se puede modificar luego de definida
tupla=(1,3,5,7,5,5,5)
##tupla[0]=9
print(tupla)
# Out:
# (1, 3, 5, 7, 5, 5, 5)

# %%
tupla.count(5)
# Out:
# 4

# %%
tupla.index(3)
# Out:
# 1

# %%
tupla=("maria",1,2,0.5555, True, False)
print(tupla)
# Out:
# ('maria', 1, 2, 0.5555, True, False)

# %%
tupla[1:4]
# Out:
# (1, 2, 0.5555)
