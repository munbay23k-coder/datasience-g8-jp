# %%
# listas -> []
# tupla -> ()
# set o conjunto -> {} - guarda elementos unicos

# %%
conjunto_a={1,3,5,7,9,9,1,3}
conjunto_b={3,5,7}
conjunto_c=[1,3,5,7,9,9,1,3]
print(conjunto_a)
print(conjunto_b)
# Out:
# {1, 3, 5, 7, 9}
# {3, 5, 7}

# %%
conjunto_a[0]=50
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 conjunto_a[0]=50
#
# TypeError: 'set' object does not support item assignment

# %%
#union
conjunto_a={1,3,5,7,9,9,1,3}
conjunto_b={3,5,7,12}

conjunto_a.union(conjunto_b)
# Out:
# {1, 3, 5, 7, 9, 12}

# %%
conjunto_a | conjunto_b
# Out:
# {1, 3, 5, 7, 9, 12}

# %%
#INTERSERCCION
conjunto_a.intersection(conjunto_b)
# Out:
# {3, 5, 7}

# %%
conjunto_a & conjunto_b
# Out:
# {3, 5, 7}

# %%
#DIFERENCIA
conjunto_a.difference(conjunto_b)
# Out:
# {1, 9}

# %%
conjunto_a - conjunto_b
# Out:
# {1, 9}

# %%
conjunto_b.difference(conjunto_a)
# Out:
# {12}

# %%
conjunto_b - conjunto_a
# Out:
# {12}

# %%
#diferencia simetrica
conjunto_a.symmetric_difference(conjunto_b)
# Out:
# {1, 9, 12}

# %%
conjunto_a ^ conjunto_b
# Out:
# {1, 9, 12}

# %%
lista = [3,3,3,3,4,5,6]
mi_conjuto= set(lista)
print(mi_conjuto)
# Out:
# {3, 4, 5, 6}

# %%
conjunto= {1,3,5}

conjunto.add(9)

print(conjunto)
# Out:
# {1, 3, 5, 9}

# %%
conjunto.remove(3)
print(conjunto)
# Out:
# {1, 5, 9}

# %%
conjunto.pop() ## es aleatorio el elemento, no se recomienda usar
# Out:
# 1

# %%
print(conjunto)
# Out:
# {5, 9}

# %%
conjunto_a={1,3,5,7,9,9,1,3}
conjunto_b={3,5,7,12}
## es para que de verdadero o falso, falso si n tienen elementos en comun
conjunto_a.isdisjoint(conjunto_b)
# Out:
# False

# %%
conjunto_a={1,3,5,7,9,9,1,3}
conjunto_b={180}
conjunto_a.isdisjoint(conjunto_b)
# Out:
# True

# %%
conjunto_a={1,3,5,7,9,9,1,3}
conjunto_b={3,5,7}
### si el conjunto a es un subconjunto de B, 
conjunto_a.issubset(conjunto_b)
# Out:
# False

# %%
conjunto_b.issubset(conjunto_a)
# Out:
# True

# %%
## si el conjunto a es un superconjunto de b, b esta dentro de a?
conjunto_a.issuperset(conjunto_b)
# Out:
# True

# %%
conjunto_b.issuperset(conjunto_a)
# Out:
# False
